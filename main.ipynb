# %% [markdown]
# ### SETUP

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd drive/MyDrive/faculdade/transcriptions/

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
# !pip install whisperx

# %% [markdown]
# ### RUN CODE

# %%
# !pip install yt-dlp dotenv

# %%
# !ls downloads

# %% [markdown]
# #### download videos

# %%
# !python transcript.py --download

# %% [markdown]
# #### transcribe videos with speakers

# %%
# !pip install matplotlib-inline
# !pip install torchcodec==0.7

# %%
# !python transcript.py --speakers --youtubers jordanmatter

# %%
print("oi")

# %% [markdown]
# ### RUN CODE TOPICS

# %%
# !pip install yt-dlp transformers torch

# %%
# !pip install bertopic sentence-transformers emoji

# %%
from google.colab import output
output.no_vertical_scroll()

# !python topic.py \
  --cleaning-profile basic \
  --debug
